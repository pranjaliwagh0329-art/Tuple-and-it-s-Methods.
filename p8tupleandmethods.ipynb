# %% [markdown]
# ## Tuple anḍ its methods

# %%
t1=()

# %%
t2=tuple()

# %%
print(type(t2))
# Out:
# <class 'tuple'>

# %%
t3=(99,30,35,38,80,98,78,54,38,22,67,100)
print(type(t3))
# Out:
# <class 'tuple'>

# %%
t3[4]
# Out:
# 80

# %%
t3[7]
# Out:
# 54

# %%
t3[1]
# Out:
# 30

# %%
t3[-7]
# Out:
# 98

# %%
t3[6:15]
# Out:
# (78, 54, 38, 22, 67, 100)

# %%
len(t3)
# Out:
# 12

# %%
t3[5:10:3]
# Out:
# (98, 38)

# %%
all(t3)
# Out:
# True

# %%
any(t3)
# Out:
# True

# %%
t3.count(100)
# Out:
# 1

# %%
s=tuple(sorted(t3))
s
# Out:
# (22, 30, 35, 38, 38, 54, 67, 78, 80, 98, 99, 100)

# %%
e=(24,9,15,66,70)
e=sorted(e, reverse=True)
e
# Out:
# [70, 66, 24, 15, 9]

# %%
S=(23,44,1,18,22,44)
index_1=S.index(1)
print(index_1)
# Out:
# 2

# %%
index_44=S.index(44)
index_44
# Out:
# 1

# %%
D=(56,45,35,65,75,86)
print(D)
# Out:
# (56, 45, 35, 65, 75, 86)

# %%
type(D)
# Out:
# tuple

# %%
D=(2,3,4,5,6)
E=(6,7,8,9,1,10)
S=D+E
S
# Out:
# (2, 3, 4, 5, 6, 6, 7, 8, 9, 1, 10)

# %%
A=('riya','siya')
B=(34,56,78,90,88)
C=A+B
C
# Out:
# ('riya', 'siya', 34, 56, 78, 90, 88)

# %%
### using Asterisk
F=("apple","banana","Cherry","strawberry","raspberry")
(white,blue,*red)=F
print(white)
print(blue)
print(red)
# Out:
# apple
# banana
# ['Cherry', 'strawberry', 'raspberry']
